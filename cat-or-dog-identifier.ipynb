# %% [markdown]
# ### Imports

# %%
import os
from PIL import Image
import tensorflow as tf
import pandas as pd
import numpy as np
import h5py
import tables as pt
import math

# %% [markdown]
# ### Parameters

# %%
# Model Saver
checkpoint_file_name = 'cat-or-dog.ckpt'
use_saved_model = False
save_model = True

# Model
channels_nb = 3 # 1 for greyscale images as input, 3 for RGB
classes_nb = 2
img_height = 90
img_width = int(math.floor(1.15*img_height)) # Made to keep the 1.15 image size ratio
learning_rate = 0.0001
weights_init_stddev = 0.01
bias_init_val = 0.01
train_keep_prob =  0.25

# Total training images : 20996
# Total validation images : 2000
# Total test images : 2000

# Batch size is the same for training and evaluation
batch_size = 50

# Training
train_steps_nb = 10000 # For each image to be used only once for training, train_steps_nb=20996/batch_size=20996/50=419.92

# Evaluation
train_eval_steps_nb = 30
validation_eval_steps_nb = 30
test_eval_steps_nb = 40 # Max : total-test-image/batch_size= 2000/50 = 40

# Regular events while training
print_starting_batch_every_x_train_step = 20
eval_every_x_train_step = 100

# %% [markdown]
# ### Constants

# %%
# Paths
cwd = os.getcwd()
images_dir = os.path.join(cwd, 'images/')
checkpoints_dir = os.path.join(cwd, 'checkpoints/')

# Storage
store = pd.HDFStore(cwd + '/store.h5')

# Load images data
images_df = store['images_df']
store.close()

# File to save model
checkpoint_file = checkpoints_dir + checkpoint_file_name

# %%
images_df.tail()
# Out:
#                                                full_path  label  width  \
# 24993   /home/hugo/Desktop/cat-or-dog/images/dog.661.jpg      1    240
# 24994  /home/hugo/Desktop/cat-or-dog/images/dog.7429.jpg      1    399
# 24995  /home/hugo/Desktop/cat-or-dog/images/dog.10948...      1    499
# 24996  /home/hugo/Desktop/cat-or-dog/images/dog.2499.jpg      1    499
# 24997  /home/hugo/Desktop/cat-or-dog/images/dog.8010.jpg      1    174
#
#        height     ratio    set_name
# 24993     179  1.340782       train
# 24994     500  0.798000       train
# 24995     375  1.330667       train
# 24996     375  1.330667  validation
# 24997     223  0.780269       train

# %% [markdown]
# ### Data preparation

# %%
train_images_labels_df = images_df[images_df['set_name'] == 'train'].reset_index(drop=True)
validation_images_labels_df = images_df[images_df['set_name'] == 'validation'].reset_index(drop=True)
test_images_labels_df = images_df[images_df['set_name'] == 'test'].reset_index(drop=True)

# %% [markdown]
# ### Helpers

# %%
def get_filepaths_and_labels(set_name):
    if set_name == 'training':
        images_labels_df = train_images_labels_df
    elif set_name == 'validation':
        images_labels_df = validation_images_labels_df
    elif set_name == 'test':
        images_labels_df = test_images_labels_df
    else:
        print 'Error, no set corresponding to this name.'
    return list(images_labels_df['full_path'].values), list(images_labels_df['label'].values)
    
def get_eval_steps_nb_from_set_name(set_name):
    if set_name == 'training':
        return train_eval_steps_nb
    elif set_name == 'validation':
        return validation_eval_steps_nb
    elif set_name == 'test':
        return test_eval_steps_nb
    else:
        print 'Error, no set corresponding to this name.'

# %% [markdown]
# ### Model

# %%
# Model helpers
def weight_init(shape):
    return tf.Variable(tf.truncated_normal(shape, stddev=weights_init_stddev))

def bias_init(shape):
    return tf.Variable(tf.constant(bias_init_val, shape=shape))

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 3, 3, 1], padding='SAME')

def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

def norm(x):
    return tf.nn.lrn(x, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75)

# %%
# Model 2
def do_inference(images, keep_prob):
    # CNN 1
    cnn1_output_length = 32
    weights_conv1 = weight_init([15, 15, channels_nb, cnn1_output_length])
    bias_conv1 = bias_init([cnn1_output_length])
    conv1 = tf.nn.relu(conv2d(images, weights_conv1) + bias_conv1)
    
    # Max pooling 1
    pool1 = max_pool_2x2(conv1)
    
    # Local response normalization 1
    norm1 = norm(conv1)
    
    # CNN 2
    cnn2_output_length = 64
    weights_conv2 = weight_init([11, 11, cnn1_output_length, cnn2_output_length])
    bias_conv2 = bias_init([cnn2_output_length])
    conv2 = tf.nn.relu(conv2d(pool1, weights_conv2) + bias_conv2)
    
    # Max pooling 2
    pool2 = max_pool_2x2(conv2)
    
    # Local response normalization 2
    norm2 = norm(pool2)
    
    # CNN 3
    cnn3_output_length = 128
    weights_conv3 = weight_init([8, 8, cnn2_output_length, cnn3_output_length])
    bias_conv3 = bias_init([cnn3_output_length])
    conv3 = tf.nn.relu(conv2d(norm2, weights_conv3) + bias_conv3)
    
    # Max pooling 3
    pool3 = max_pool_2x2(conv3)
    
    # Local response normalization 3
    norm3 = norm(pool3)
    
    # CNN 4
    cnn4_output_length = 256
    weights_conv4 = weight_init([5, 5, cnn3_output_length, cnn4_output_length])
    bias_conv4 = bias_init([cnn4_output_length])
    conv4 = tf.nn.relu(conv2d(norm3, weights_conv4) + bias_conv4)
    
    # Local response normalization 4
    norm4 = norm(conv4)
    
    # Max pooling 4
    pool4 = max_pool_2x2(norm4)
    
    # Reshape for fully connected layers
    pool4_flat = tf.reshape(pool4, [batch_size, -1])
    pool4_flat_output_length = pool4_flat.get_shape()[1].value
    
    # Fully connected 1
    fc1_units = 2048
    weights_fc1 = weight_init([pool4_flat_output_length, fc1_units])
    bias_fc1 = bias_init([fc1_units])
    fc1 = tf.nn.relu(tf.matmul(pool4_flat, weights_fc1) + bias_fc1)
    
    # Fully connected 2
    fc2_units = 2048
    weights_fc2 = weight_init([fc1_units, fc2_units])
    bias_fc2 = bias_init([fc2_units])
    fc2 = tf.nn.relu(tf.matmul(fc1, weights_fc2) + bias_fc2)
    
    # Drop out
    drop = tf.nn.dropout(fc2, keep_prob)
    
    # Fully connected 3
    fc3_units = 2048
    weights_fc3 = weight_init([fc2_units, fc3_units])
    bias_fc3 = bias_init([fc3_units])
    fc3 = tf.nn.relu(tf.matmul(drop, weights_fc3) + bias_fc3)
    
    # Fully connected 4
    fc4_units = 2048
    weights_fc4 = weight_init([fc3_units, fc4_units])
    bias_fc4 = bias_init([fc4_units])
    fc4 = tf.nn.relu(tf.matmul(fc3, weights_fc4) + bias_fc4)

    # Linear output
    weights_lin = weight_init([fc4_units, classes_nb])
    bias_lin = bias_init([classes_nb])
    y = tf.matmul(fc4, weights_lin) + bias_lin
    return y

# %% [markdown]
# ### Operations helpers

# %%
def get_images_labels_batch(set_name, is_eval):
    # Set queue
    filenames_str, labels_str = get_filepaths_and_labels(set_name)
    # convert string into tensors
    filenames = tf.convert_to_tensor(filenames_str, dtype=tf.string)
    labels = tf.convert_to_tensor(labels_str, dtype=tf.int32)
    
    filename, label = tf.train.slice_input_producer([filenames, labels], shuffle=True)
    
    # Add image reader
    image_content = tf.read_file(filename)
    image = tf.image.decode_jpeg(image_content, channels=channels_nb)
    
    if is_eval:
        # Resize image to the fixed image size
        image_prepared = tf.image.resize_images(image, [img_height, img_width], method=1)
        
    else:
        # If is training, apply multiple images transformation to artificially multiply the number of training images
        image_prepared = tf.image.resize_images(image, [img_height, img_width], method=1)
        
        # Randomly flip the image horizontally.
        image_prepared = tf.image.random_flip_left_right(image_prepared)

        # Randomly change image brightness
        image_prepared = tf.image.random_brightness(image_prepared, max_delta=0.5)
        
        # Randomly change image contrast
        image_prepared = tf.image.random_contrast(image_prepared, lower=0.2, upper=1.8)

    # Labels must be in the one_hot format
    label_one_hot = tf.one_hot(label, classes_nb)
    
    # Create batches
    image_batch, label_batch = tf.train.batch([image_prepared, label_one_hot], batch_size=batch_size)
    
    return image_batch, label_batch
    

def get_train_op(ys, labels, learning_rate):
    cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(ys, labels))
    train_op = tf.train.AdamOptimizer(learning_rate).minimize(cross_entropy)
    return train_op

def do_eval(sess, images_op, labels_op, keep_prob, accuracy_op, set_name, images, labels):
    # set_name can be 'training', 'validation' or 'test'
    print('\nEvaluating on {} set...'.format(set_name))
    eval_steps_nb = get_eval_steps_nb_from_set_name(set_name)
    
    accs = np.array([])
    for eval_step in range(eval_steps_nb):
        images_val, labels_val = sess.run([images_op, labels_op])
        batch_acc = sess.run([accuracy_op], feed_dict={
                        images: images_val,
                        labels: labels_val,
                        keep_prob: 1
                    })
        accs = np.append(accs, batch_acc)
    
    acc = np.mean(accs)
    print 'Accuracy on {} set is : {}'.format(set_name, acc)

# %% [markdown]
# ### Train

# %%
def do_train():
    with tf.Graph().as_default():
        # Create (image, label) tuples batches queue for training
        images_op, labels_op = get_images_labels_batch(set_name='training', is_eval=False)
        
        # Create (image, label) tuples batches queue for evaluation on each type
        eval_train_images_op, eval_train_labels_op = get_images_labels_batch(set_name='training', is_eval=True)
        eval_validation_images_op, eval_validation_labels_op = get_images_labels_batch(set_name='validation', is_eval=True)
        eval_test_images_op, eval_test_labels_op = get_images_labels_batch(set_name='test', is_eval=True)
        
        # Create placeholders
        images = tf.placeholder(tf.float32, shape=[batch_size, img_height, img_width, channels_nb])
        labels = tf.placeholder(tf.int32, shape=[batch_size, classes_nb])
        keep_prob = tf.placeholder(tf.float32)

        # Get model inference
        ys = do_inference(images, keep_prob)

        # Define train_op
        train_op = get_train_op(ys, labels, learning_rate)
        
        # Define accuracy_op
        correct_prediction = tf.equal(tf.argmax(ys,1), tf.argmax(labels,1))
        accuracy_op = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

        # Create session and initialize the variables
        sess = tf.Session()
        
        # Create a saver for writing/loading training checkpoints.
        saver = tf.train.Saver()
        
        # Initialize the variables.
        if not use_saved_model:
            sess.run(tf.initialize_all_variables())
        else:
            print 'Loading saved model...'
            saver.restore(sess, checkpoint_file)
        

        # Coordinate the (image, label) batches loading from queue
        coord = tf.train.Coordinator()
        threads = tf.train.start_queue_runners(coord=coord, sess=sess)

        # Train on the examples of the training set
        for train_step in range(train_steps_nb):
            if train_step % print_starting_batch_every_x_train_step == 0 and train_step !=0:
                print('Starting training on batch {} / {}'.format(train_step, train_steps_nb - 1))
            
            images_val, labels_val = sess.run([images_op, labels_op])
            
            sess.run([train_op], feed_dict={
                    images: images_val,
                    labels: labels_val,
                    keep_prob: train_keep_prob
                })
            
            # Regularly evaluate on the training and validation sets
            if train_step % eval_every_x_train_step == 0 :
                # Evaluate on training set
                do_eval(sess = sess,
                        images_op = eval_train_images_op,
                        labels_op = eval_train_labels_op,
                        images = images,
                        labels = labels,
                        keep_prob = keep_prob,
                        accuracy_op = accuracy_op,
                        set_name = 'training')
                
                # Evaluate on validation set
                do_eval(sess = sess,
                        images_op = eval_validation_images_op,
                        labels_op = eval_validation_labels_op,
                        images = images,
                        labels = labels,
                        keep_prob = keep_prob,
                        accuracy_op = accuracy_op,
                        set_name = 'validation')
                
                # Save model
                if save_model :
                    print('Saving model...')
                    saver.save(sess, checkpoint_file)
                    print 'Model saved.\n\n'
            
        # Evaluate on test set
        do_eval(sess = sess,
                images_op = eval_test_images_op,
                labels_op = eval_test_labels_op,
                images = images,
                labels = labels,
                keep_prob = keep_prob,
                accuracy_op = accuracy_op,
                set_name = 'test')
        
        # Save model
        if save_model :
            print('Saving model...')
            saver.save(sess, checkpoint_file)
            print 'Model saved.'
    
        # Stop the queue threads and close the session
        coord.request_stop()
        coord.join(threads)
        sess.close()
        print 'The end.'

# %%
do_train()
# Out:
# Evaluating on training set...
# Accuracy on training set is : 0.477999999126
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.501333328088
# Saving model...
# Model saved.
#
#
# Starting training on batch 20 / 9999
# Starting training on batch 40 / 9999
# Starting training on batch 60 / 9999
# Starting training on batch 80 / 9999
# Starting training on batch 100 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.489333331585
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.508000002305
# Saving model...
# Model saved.
#
#
# Starting training on batch 120 / 9999
# Starting training on batch 140 / 9999
# Starting training on batch 160 / 9999
# Starting training on batch 180 / 9999
# Starting training on batch 200 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.519999996821
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.494666665792
# Saving model...
# Model saved.
#
#
# Starting training on batch 220 / 9999
# Starting training on batch 240 / 9999
# Starting training on batch 260 / 9999
# Starting training on batch 280 / 9999
# Starting training on batch 300 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.503999998172
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.500000001987
# Saving model...
# Model saved.
#
#
# Starting training on batch 320 / 9999
# Starting training on batch 340 / 9999
# Starting training on batch 360 / 9999
# Starting training on batch 380 / 9999
# Starting training on batch 400 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.562000002464
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.551333334049
# Saving model...
# Model saved.
#
#
# Starting training on batch 420 / 9999
# Starting training on batch 440 / 9999
# Starting training on batch 460 / 9999
# Starting training on batch 480 / 9999
# Starting training on batch 500 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.491333329678
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.527333336075
# Saving model...
# Model saved.
#
#
# Starting training on batch 520 / 9999
# Starting training on batch 540 / 9999
# Starting training on batch 560 / 9999
# Starting training on batch 580 / 9999
# Starting training on batch 600 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.563333333532
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.572666665912
# Saving model...
# Model saved.
#
#
# Starting training on batch 620 / 9999
# Starting training on batch 640 / 9999
# Starting training on batch 660 / 9999
# Starting training on batch 680 / 9999
# Starting training on batch 700 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.594000001748
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.586000000437
# Saving model...
# Model saved.
#
#
# Starting training on batch 720 / 9999
# Starting training on batch 740 / 9999
# Starting training on batch 760 / 9999
# Starting training on batch 780 / 9999
# Starting training on batch 800 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.596000007788
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.598666668932
# Saving model...
# Model saved.
#
#
# Starting training on batch 820 / 9999
# Starting training on batch 840 / 9999
# Starting training on batch 860 / 9999
# Starting training on batch 880 / 9999
# Starting training on batch 900 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.602666670084
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.58800000747
# Saving model...
# Model saved.
#
#
# Starting training on batch 920 / 9999
# Starting training on batch 940 / 9999
# Starting training on batch 960 / 9999
# Starting training on batch 980 / 9999
# Starting training on batch 1000 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.555333334208
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.551333337029
# Saving model...
# Model saved.
#
#
# Starting training on batch 1020 / 9999
# Starting training on batch 1040 / 9999
# Starting training on batch 1060 / 9999
# Starting training on batch 1080 / 9999
# Starting training on batch 1100 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.512666664521
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.5146666646
# Saving model...
# Model saved.
#
#
# Starting training on batch 1120 / 9999
# Starting training on batch 1140 / 9999
# Starting training on batch 1160 / 9999
# Starting training on batch 1180 / 9999
# Starting training on batch 1200 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.526666667064
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.527333333095
# Saving model...
# Model saved.
#
#
# Starting training on batch 1220 / 9999
# Starting training on batch 1240 / 9999
# Starting training on batch 1260 / 9999
# Starting training on batch 1280 / 9999
# Starting training on batch 1300 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.612666672468
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.610666669408
# Saving model...
# Model saved.
#
#
# Starting training on batch 1320 / 9999
# Starting training on batch 1340 / 9999
# Starting training on batch 1360 / 9999
# Starting training on batch 1380 / 9999
# Starting training on batch 1400 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.658666669329
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.653333342075
# Saving model...
# Model saved.
#
#
# Starting training on batch 1420 / 9999
# Starting training on batch 1440 / 9999
# Starting training on batch 1460 / 9999
# Starting training on batch 1480 / 9999
# Starting training on batch 1500 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.643333337704
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.646666667859
# Saving model...
# Model saved.
#
#
# Starting training on batch 1520 / 9999
# Starting training on batch 1540 / 9999
# Starting training on batch 1560 / 9999
# Starting training on batch 1580 / 9999
# Starting training on batch 1600 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.685333339373
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.655333332221
# Saving model...
# Model saved.
#
#
# Starting training on batch 1620 / 9999
# Starting training on batch 1640 / 9999
# Starting training on batch 1660 / 9999
# Starting training on batch 1680 / 9999
# Starting training on batch 1700 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.660000000397
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.669999998808
# Saving model...
# Model saved.
#
#
# Starting training on batch 1720 / 9999
# Starting training on batch 1740 / 9999
# Starting training on batch 1760 / 9999
# Starting training on batch 1780 / 9999
# Starting training on batch 1800 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.677333340049
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.66133333842
# Saving model...
# Model saved.
#
#
# Starting training on batch 1820 / 9999
# Starting training on batch 1840 / 9999
# Starting training on batch 1860 / 9999
# Starting training on batch 1880 / 9999
# Starting training on batch 1900 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.707333334287
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.678000001113
# Saving model...
# Model saved.
#
#
# Starting training on batch 1920 / 9999
# Starting training on batch 1940 / 9999
# Starting training on batch 1960 / 9999
# Starting training on batch 1980 / 9999
# Starting training on batch 2000 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.678666675091
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.694000003735
# Saving model...
# Model saved.
#
#
# Starting training on batch 2020 / 9999
# Starting training on batch 2040 / 9999
# Starting training on batch 2060 / 9999
# Starting training on batch 2080 / 9999
# Starting training on batch 2100 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.686000011365
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.676666671038
# Saving model...
# Model saved.
#
#
# Starting training on batch 2120 / 9999
# Starting training on batch 2140 / 9999
# Starting training on batch 2160 / 9999
# Starting training on batch 2180 / 9999
# Starting training on batch 2200 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.686666675409
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.693333337704
# Saving model...
# Model saved.
#
#
# Starting training on batch 2220 / 9999
# Starting training on batch 2240 / 9999
# Starting training on batch 2260 / 9999
# Starting training on batch 2280 / 9999
# Starting training on batch 2300 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.689333339532
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.676666667064
# Saving model...
# Model saved.
#
#
# Starting training on batch 2320 / 9999
# Starting training on batch 2340 / 9999
# Starting training on batch 2360 / 9999
# Starting training on batch 2380 / 9999
# Starting training on batch 2400 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.701333332062
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.700000009934
# Saving model...
# Model saved.
#
#
# Starting training on batch 2420 / 9999
# Starting training on batch 2440 / 9999
# Starting training on batch 2460 / 9999
# Starting training on batch 2480 / 9999
# Starting training on batch 2500 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.706000004212
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.690000005563
# Saving model...
# Model saved.
#
#
# Starting training on batch 2520 / 9999
# Starting training on batch 2540 / 9999
# Starting training on batch 2560 / 9999
# Starting training on batch 2580 / 9999
# Starting training on batch 2600 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.678000005086
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.687333339453
# Saving model...
# Model saved.
#
#
# Starting training on batch 2620 / 9999
# Starting training on batch 2640 / 9999
# Starting training on batch 2660 / 9999
# Starting training on batch 2680 / 9999
# Starting training on batch 2700 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.703333338102
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.687333339453
# Saving model...
# Model saved.
#
#
# Starting training on batch 2720 / 9999
# Starting training on batch 2740 / 9999
# Starting training on batch 2760 / 9999
# Starting training on batch 2780 / 9999
# Starting training on batch 2800 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.720666670799
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.703999998172
# Saving model...
# Model saved.
#
#
# Starting training on batch 2820 / 9999
# Starting training on batch 2840 / 9999
# Starting training on batch 2860 / 9999
# Starting training on batch 2880 / 9999
# Starting training on batch 2900 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.715333336592
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.705333342155
# Saving model...
# Model saved.
#
#
# Starting training on batch 2920 / 9999
# Starting training on batch 2940 / 9999
# Starting training on batch 2960 / 9999
# Starting training on batch 2980 / 9999
# Starting training on batch 3000 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.716000002623
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.711333332459
# Saving model...
# Model saved.
#
#
# Starting training on batch 3020 / 9999
# Starting training on batch 3040 / 9999
# Starting training on batch 3060 / 9999
# Starting training on batch 3080 / 9999
# Starting training on batch 3100 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.725333335002
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.729999999205
# Saving model...
# Model saved.
#
#
# Starting training on batch 3120 / 9999
# Starting training on batch 3140 / 9999
# Starting training on batch 3160 / 9999
# Starting training on batch 3180 / 9999
# Starting training on batch 3200 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.70666667223
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.666666666667
# Saving model...
# Model saved.
#
#
# Starting training on batch 3220 / 9999
# Starting training on batch 3240 / 9999
# Starting training on batch 3260 / 9999
# Starting training on batch 3280 / 9999
# Starting training on batch 3300 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.742666669687
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.717333328724
# Saving model...
# Model saved.
#
#
# Starting training on batch 3320 / 9999
# Starting training on batch 3340 / 9999
# Starting training on batch 3360 / 9999
# Starting training on batch 3380 / 9999
# Starting training on batch 3400 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.722000004848
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.713333334525
# Saving model...
# Model saved.
#
#
# Starting training on batch 3420 / 9999
# Starting training on batch 3440 / 9999
# Starting training on batch 3460 / 9999
# Starting training on batch 3480 / 9999
# Starting training on batch 3500 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.734666667382
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.734000001351
# Saving model...
# Model saved.
#
#
# Starting training on batch 3520 / 9999
# Starting training on batch 3540 / 9999
# Starting training on batch 3560 / 9999
# Starting training on batch 3580 / 9999
# Starting training on batch 3600 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.757999998331
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.73333333532
# Saving model...
# Model saved.
#
#
# Starting training on batch 3620 / 9999
# Starting training on batch 3640 / 9999
# Starting training on batch 3660 / 9999
# Starting training on batch 3680 / 9999
# Starting training on batch 3700 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.736666665475
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.7353333354
# Saving model...
# Model saved.
#
#
# Starting training on batch 3720 / 9999
# Starting training on batch 3740 / 9999
# Starting training on batch 3760 / 9999
# Starting training on batch 3780 / 9999
# Starting training on batch 3800 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.749333337943
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.735333333413
# Saving model...
# Model saved.
#
#
# Starting training on batch 3820 / 9999
# Starting training on batch 3840 / 9999
# Starting training on batch 3860 / 9999
# Starting training on batch 3880 / 9999
# Starting training on batch 3900 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.745333339771
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.712666671475
# Saving model...
# Model saved.
#
#
# Starting training on batch 3920 / 9999
# Starting training on batch 3940 / 9999
# Starting training on batch 3960 / 9999
# Starting training on batch 3980 / 9999
# Starting training on batch 4000 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.734666667382
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.742000003656
# Saving model...
# Model saved.
#
#
# Starting training on batch 4020 / 9999
# Starting training on batch 4040 / 9999
# Starting training on batch 4060 / 9999
# Starting training on batch 4080 / 9999
# Starting training on batch 4100 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.772000002861
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.729999997218
# Saving model...
# Model saved.
#
#
# Starting training on batch 4120 / 9999
# Starting training on batch 4140 / 9999
# Starting training on batch 4160 / 9999
# Starting training on batch 4180 / 9999
# Starting training on batch 4200 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.751333330075
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.73800000747
# Saving model...
# Model saved.
#
#
# Starting training on batch 4220 / 9999
# Starting training on batch 4240 / 9999
# Starting training on batch 4260 / 9999
# Starting training on batch 4280 / 9999
# Starting training on batch 4300 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.759999996424
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.740000005563
# Saving model...
# Model saved.
#
#
# Starting training on batch 4320 / 9999
# Starting training on batch 4340 / 9999
# Starting training on batch 4360 / 9999
# Starting training on batch 4380 / 9999
# Starting training on batch 4400 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.787999989589
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.760666672389
# Saving model...
# Model saved.
#
#
# Starting training on batch 4420 / 9999
# Starting training on batch 4440 / 9999
# Starting training on batch 4460 / 9999
# Starting training on batch 4480 / 9999
# Starting training on batch 4500 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.764000000556
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.729333337148
# Saving model...
# Model saved.
#
#
# Starting training on batch 4520 / 9999
# Starting training on batch 4540 / 9999
# Starting training on batch 4560 / 9999
# Starting training on batch 4580 / 9999
# Starting training on batch 4600 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.794666659832
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.759999998411
# Saving model...
# Model saved.
#
#
# Starting training on batch 4620 / 9999
# Starting training on batch 4640 / 9999
# Starting training on batch 4660 / 9999
# Starting training on batch 4680 / 9999
# Starting training on batch 4700 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.766666666667
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.714666668574
# Saving model...
# Model saved.
#
#
# Starting training on batch 4720 / 9999
# Starting training on batch 4740 / 9999
# Starting training on batch 4760 / 9999
# Starting training on batch 4780 / 9999
# Starting training on batch 4800 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.773999998967
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.737333331505
# Saving model...
# Model saved.
#
#
# Starting training on batch 4820 / 9999
# Starting training on batch 4840 / 9999
# Starting training on batch 4860 / 9999
# Starting training on batch 4880 / 9999
# Starting training on batch 4900 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.769999990861
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.759333326419
# Saving model...
# Model saved.
#
#
# Starting training on batch 4920 / 9999
# Starting training on batch 4940 / 9999
# Starting training on batch 4960 / 9999
# Starting training on batch 4980 / 9999
# Starting training on batch 5000 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.767333332698
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.743333331744
# Saving model...
# Model saved.
#
#
# Starting training on batch 5020 / 9999
# Starting training on batch 5040 / 9999
# Starting training on batch 5060 / 9999
# Starting training on batch 5080 / 9999
# Starting training on batch 5100 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.793333329757
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.740666665634
# Saving model...
# Model saved.
#
#
# Starting training on batch 5120 / 9999
# Starting training on batch 5140 / 9999
# Starting training on batch 5160 / 9999
# Starting training on batch 5180 / 9999
# Starting training on batch 5200 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.777999995152
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.745999999841
# Saving model...
# Model saved.
#
#
# Starting training on batch 5220 / 9999
# Starting training on batch 5240 / 9999
# Starting training on batch 5260 / 9999
# Starting training on batch 5280 / 9999
# Starting training on batch 5300 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.785999991496
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.744666667779
# Saving model...
# Model saved.
#
#
# Starting training on batch 5320 / 9999
# Starting training on batch 5340 / 9999
# Starting training on batch 5360 / 9999
# Starting training on batch 5380 / 9999
# Starting training on batch 5400 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.773333328962
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.737333333492
# Saving model...
# Model saved.
#
#
# Starting training on batch 5420 / 9999
# Starting training on batch 5440 / 9999
# Starting training on batch 5460 / 9999
# Starting training on batch 5480 / 9999
# Starting training on batch 5500 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.782000003258
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.750666662057
# Saving model...
# Model saved.
#
#
# Starting training on batch 5520 / 9999
# Starting training on batch 5540 / 9999
# Starting training on batch 5560 / 9999
# Starting training on batch 5580 / 9999
# Starting training on batch 5600 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.775999993086
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.753333330154
# Saving model...
# Model saved.
#
#
# Starting training on batch 5620 / 9999
# Starting training on batch 5640 / 9999
# Starting training on batch 5660 / 9999
# Starting training on batch 5680 / 9999
# Starting training on batch 5700 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.795333325863
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.730666671197
# Saving model...
# Model saved.
#
#
# Starting training on batch 5720 / 9999
# Starting training on batch 5740 / 9999
# Starting training on batch 5760 / 9999
# Starting training on batch 5780 / 9999
# Starting training on batch 5800 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.76933333079
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.768666660786
# Saving model...
# Model saved.
#
#
# Starting training on batch 5820 / 9999
# Starting training on batch 5840 / 9999
# Starting training on batch 5860 / 9999
# Starting training on batch 5880 / 9999
# Starting training on batch 5900 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.771999996901
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.7353333354
# Saving model...
# Model saved.
#
#
# Starting training on batch 5920 / 9999
# Starting training on batch 5940 / 9999
# Starting training on batch 5960 / 9999
# Starting training on batch 5980 / 9999
# Starting training on batch 6000 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.780666665236
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.747999997934
# Saving model...
# Model saved.
#
#
# Starting training on batch 6020 / 9999
# Starting training on batch 6040 / 9999
# Starting training on batch 6060 / 9999
# Starting training on batch 6080 / 9999
# Starting training on batch 6100 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.7926666677
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.731333333254
# Saving model...
# Model saved.
#
#
# Starting training on batch 6120 / 9999
# Starting training on batch 6140 / 9999
# Starting training on batch 6160 / 9999
# Starting training on batch 6180 / 9999
# Starting training on batch 6200 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.807333330313
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.756666660309
# Saving model...
# Model saved.
#
#
# Starting training on batch 6220 / 9999
# Starting training on batch 6240 / 9999
# Starting training on batch 6260 / 9999
# Starting training on batch 6280 / 9999
# Starting training on batch 6300 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.785333331426
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.763999998569
# Saving model...
# Model saved.
#
#
# Starting training on batch 6320 / 9999
# Starting training on batch 6340 / 9999
# Starting training on batch 6360 / 9999
# Starting training on batch 6380 / 9999
# Starting training on batch 6400 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.808666660388
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.763333330552
# Saving model...
# Model saved.
#
#
# Starting training on batch 6420 / 9999
# Starting training on batch 6440 / 9999
# Starting training on batch 6460 / 9999
# Starting training on batch 6480 / 9999
# Starting training on batch 6500 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.803333326181
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.744666667779
# Saving model...
# Model saved.
#
#
# Starting training on batch 6520 / 9999
# Starting training on batch 6540 / 9999
# Starting training on batch 6560 / 9999
# Starting training on batch 6580 / 9999
# Starting training on batch 6600 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.820666658878
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.778666661183
# Saving model...
# Model saved.
#
#
# Starting training on batch 6620 / 9999
# Starting training on batch 6640 / 9999
# Starting training on batch 6660 / 9999
# Starting training on batch 6680 / 9999
# Starting training on batch 6700 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.787999989589
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.736666665475
# Saving model...
# Model saved.
#
#
# Starting training on batch 6720 / 9999
# Starting training on batch 6740 / 9999
# Starting training on batch 6760 / 9999
# Starting training on batch 6780 / 9999
# Starting training on batch 6800 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.815999992688
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.750666670005
# Saving model...
# Model saved.
#
#
# Starting training on batch 6820 / 9999
# Starting training on batch 6840 / 9999
# Starting training on batch 6860 / 9999
# Starting training on batch 6880 / 9999
# Starting training on batch 6900 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.808666664362
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.772666664918
# Saving model...
# Model saved.
#
#
# Starting training on batch 6920 / 9999
# Starting training on batch 6940 / 9999
# Starting training on batch 6960 / 9999
# Starting training on batch 6980 / 9999
# Starting training on batch 7000 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.801333332062
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.748666669925
# Saving model...
# Model saved.
#
#
# Starting training on batch 7020 / 9999
# Starting training on batch 7040 / 9999
# Starting training on batch 7060 / 9999
# Starting training on batch 7080 / 9999
# Starting training on batch 7100 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.81199999253
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.783999995391
# Saving model...
# Model saved.
#
#
# Starting training on batch 7120 / 9999
# Starting training on batch 7140 / 9999
# Starting training on batch 7160 / 9999
# Starting training on batch 7180 / 9999
# Starting training on batch 7200 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.808666660388
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.76933332483
# Saving model...
# Model saved.
#
#
# Starting training on batch 7220 / 9999
# Starting training on batch 7240 / 9999
# Starting training on batch 7260 / 9999
# Starting training on batch 7280 / 9999
# Starting training on batch 7300 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.81466665864
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.770666662852
# Saving model...
# Model saved.
#
#
# Starting training on batch 7320 / 9999
# Starting training on batch 7340 / 9999
# Starting training on batch 7360 / 9999
# Starting training on batch 7380 / 9999
# Starting training on batch 7400 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.803333328168
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.76666666468
# Saving model...
# Model saved.
#
#
# Starting training on batch 7420 / 9999
# Starting training on batch 7440 / 9999
# Starting training on batch 7460 / 9999
# Starting training on batch 7480 / 9999
# Starting training on batch 7500 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.82399999698
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.767333328724
# Saving model...
# Model saved.
#
#
# Starting training on batch 7520 / 9999
# Starting training on batch 7540 / 9999
# Starting training on batch 7560 / 9999
# Starting training on batch 7580 / 9999
# Starting training on batch 7600 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.815333326658
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.774666664998
# Saving model...
# Model saved.
#
#
# Starting training on batch 7620 / 9999
# Starting training on batch 7640 / 9999
# Starting training on batch 7660 / 9999
# Starting training on batch 7680 / 9999
# Starting training on batch 7700 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.81666666468
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.755999996265
# Saving model...
# Model saved.
#
#
# Starting training on batch 7720 / 9999
# Starting training on batch 7740 / 9999
# Starting training on batch 7760 / 9999
# Starting training on batch 7780 / 9999
# Starting training on batch 7800 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.823333328962
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.765333332618
# Saving model...
# Model saved.
#
#
# Starting training on batch 7820 / 9999
# Starting training on batch 7840 / 9999
# Starting training on batch 7860 / 9999
# Starting training on batch 7880 / 9999
# Starting training on batch 7900 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.820666656892
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.772666656971
# Saving model...
# Model saved.
#
#
# Starting training on batch 7920 / 9999
# Starting training on batch 7940 / 9999
# Starting training on batch 7960 / 9999
# Starting training on batch 7980 / 9999
# Starting training on batch 8000 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.807999990384
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.753333332141
# Saving model...
# Model saved.
#
#
# Starting training on batch 8020 / 9999
# Starting training on batch 8040 / 9999
# Starting training on batch 8060 / 9999
# Starting training on batch 8080 / 9999
# Starting training on batch 8100 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.835333329439
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.789333333572
# Saving model...
# Model saved.
#
#
# Starting training on batch 8120 / 9999
# Starting training on batch 8140 / 9999
# Starting training on batch 8160 / 9999
# Starting training on batch 8180 / 9999
# Starting training on batch 8200 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.831999991337
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.768666660786
# Saving model...
# Model saved.
#
#
# Starting training on batch 8220 / 9999
# Starting training on batch 8240 / 9999
# Starting training on batch 8260 / 9999
# Starting training on batch 8280 / 9999
# Starting training on batch 8300 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.830666661263
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.774000006914
# Saving model...
# Model saved.
#
#
# Starting training on batch 8320 / 9999
# Starting training on batch 8340 / 9999
# Starting training on batch 8360 / 9999
# Starting training on batch 8380 / 9999
# Starting training on batch 8400 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.83333332936
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.769999998808
# Saving model...
# Model saved.
#
#
# Starting training on batch 8420 / 9999
# Starting training on batch 8440 / 9999
# Starting training on batch 8460 / 9999
# Starting training on batch 8480 / 9999
# Starting training on batch 8500 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.8146666646
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.769333334764
# Saving model...
# Model saved.
#
#
# Starting training on batch 8520 / 9999
# Starting training on batch 8540 / 9999
# Starting training on batch 8560 / 9999
# Starting training on batch 8580 / 9999
# Starting training on batch 8600 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.819999992847
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.780000003179
# Saving model...
# Model saved.
#
#
# Starting training on batch 8620 / 9999
# Starting training on batch 8640 / 9999
# Starting training on batch 8660 / 9999
# Starting training on batch 8680 / 9999
# Starting training on batch 8700 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.827333325148
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.76199999849
# Saving model...
# Model saved.
#
#
# Starting training on batch 8720 / 9999
# Starting training on batch 8740 / 9999
# Starting training on batch 8760 / 9999
# Starting training on batch 8780 / 9999
# Starting training on batch 8800 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.817333328724
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.77133333087
# Saving model...
# Model saved.
#
#
# Starting training on batch 8820 / 9999
# Starting training on batch 8840 / 9999
# Starting training on batch 8860 / 9999
# Starting training on batch 8880 / 9999
# Starting training on batch 8900 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.855999992291
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.776666665077
# Saving model...
# Model saved.
#
#
# Starting training on batch 8920 / 9999
# Starting training on batch 8940 / 9999
# Starting training on batch 8960 / 9999
# Starting training on batch 8980 / 9999
# Starting training on batch 9000 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.837333337466
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.778666665157
# Saving model...
# Model saved.
#
#
# Starting training on batch 9020 / 9999
# Starting training on batch 9040 / 9999
# Starting training on batch 9060 / 9999
# Starting training on batch 9080 / 9999
# Starting training on batch 9100 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.842666661739
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.767333330711
# Saving model...
# Model saved.
#
#
# Starting training on batch 9120 / 9999
# Starting training on batch 9140 / 9999
# Starting training on batch 9160 / 9999
# Starting training on batch 9180 / 9999
# Starting training on batch 9200 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.861333328485
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.775999993086
# Saving model...
# Model saved.
#
#
# Starting training on batch 9220 / 9999
# Starting training on batch 9240 / 9999
# Starting training on batch 9260 / 9999
# Starting training on batch 9280 / 9999
# Starting training on batch 9300 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.846666659911
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.753333332141
# Saving model...
# Model saved.
#
#
# Starting training on batch 9320 / 9999
# Starting training on batch 9340 / 9999
# Starting training on batch 9360 / 9999
# Starting training on batch 9380 / 9999
# Starting training on batch 9400 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.857999998331
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.793999997775
# Saving model...
# Model saved.
#
#
# Starting training on batch 9420 / 9999
# Starting training on batch 9440 / 9999
# Starting training on batch 9460 / 9999
# Starting training on batch 9480 / 9999
# Starting training on batch 9500 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.837333327532
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.768666668733
# Saving model...
# Model saved.
#
#
# Starting training on batch 9520 / 9999
# Starting training on batch 9540 / 9999
# Starting training on batch 9560 / 9999
# Starting training on batch 9580 / 9999
# Starting training on batch 9600 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.834666661421
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.775333331029
# Saving model...
# Model saved.
#
#
# Starting training on batch 9620 / 9999
# Starting training on batch 9640 / 9999
# Starting training on batch 9660 / 9999
# Starting training on batch 9680 / 9999
# Starting training on batch 9700 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.829333331188
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.777333325148
# Saving model...
# Model saved.
#
#
# Starting training on batch 9720 / 9999
# Starting training on batch 9740 / 9999
# Starting training on batch 9760 / 9999
# Starting training on batch 9780 / 9999
# Starting training on batch 9800 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.833333331347
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.772666668892
# Saving model...
# Model saved.
#
#
# Starting training on batch 9820 / 9999
# Starting training on batch 9840 / 9999
# Starting training on batch 9860 / 9999
# Starting training on batch 9880 / 9999
# Starting training on batch 9900 / 9999
#
# Evaluating on training set...
# Accuracy on training set is : 0.820666656892
#
# Evaluating on validation set...
# Accuracy on validation set is : 0.760000002384
# Saving model...
# Model saved.
#
#
# Starting training on batch 9920 / 9999
# Starting training on batch 9940 / 9999
# Starting training on batch 9960 / 9999
# Starting training on batch 9980 / 9999
#
# Evaluating on test set...
# Accuracy on test set is : 0.788499993086
# Saving model...
# Model saved.
# The end.
